# %%
import requests

url = "https://appvector.io/aso-tool/api/v1/reviews/?appId=com.whatsapp&page=2"

payload = ""
headers = {
  'Authorization': 'Token 45e26452e0ddf6a2b69c4a8a41bd9df7777d20ca'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"count":1717235,"next":"https://appvector.io/aso-tool/api/v1/reviews/?appId=com.whatsapp&page=3","previous":"https://appvector.io/aso-tool/api/v1/reviews/?appId=com.whatsapp","results":[{"review_url":"https://play.google.com/store/apps/details?id=com.whatsapp&reviewId=gp:AOqpTOHY6TKb5-IQSHh-7PID1n9m_4SnCQR5NgWVXRJAzSqnox_S8PbNrG03QzLfjtKLrGYM4O4gP3OMfmMIb74","text":"Dengeras app hacker hack my phon","star":5,"thumbs_up":0,"user_name":"Prajwal Shirsath","user_image":"https://play-lh.googleusercontent.com/a/AATXAJwWHRafayburyDs2nmg0mO1iSDx3m979XBWheaF=mo","developer_reply":null,"version":null,"review_date":"2022-02-01","date":"2022-02-01","anomaly":false},{"review_url":"https://play.google.com/store/apps/details?id=com.whatsapp&reviewId=gp:AOqpTOEiQhl68PgbnD5mXc77EQ8ZP9xw63FwXnE-ZLkGJiLajiJZ38FipKzUZzhaJCKxG7x5dpAcq9HvWfLbnFY","text":"nice","star":2,"thumbs_up":0,"user_name":"Sk Babu","user_image":"https://play-lh.googleusercontent.com/a/AATXAJy9YWiS-rWaft-dsQMk0e0my1MKM9L1ebPBuQQ-=mo
# ...
